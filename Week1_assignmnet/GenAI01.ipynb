# %% [markdown]
# ## 第一週作業 02/18: 在Colab中畫一個函數圖形
# 📌 臺灣師範大學 | 613K0019C | AI所碩一 | 劉思廷

# %% [markdown]
# ✔️ **程式碼說明**
#
# * `%matplotlib inline` 是IPython中的一個Magic command
#
# * 讓 `matplotlib` 繪製的圖表直接顯示在輸出區域，而不需額外的 `plt.show()`
# * 適用於Jupyter Notebook和Google Colab

# %%
""" 啟用內嵌繪圖模式，讓 matplotlib 圖表直接顯示在輸出區塊 """
# %matplotlib inline

# %% [markdown]
# ✔️ **程式碼說明**
# * `numpy(np)`: 提供數值運算功能，適用矩陣運算與科學計算
# * `matplotlib.pyplot(plt)`: 常用的**繪圖套件**
# * `seaborn(sns)`: 基於Matplotlib，提供**美觀統計圖表**，適用於**數據視覺化**
# * `pandas(pd)`: 用於**處理表格數據**，支援數據清理、分析與操作

# %%
""" Required four-line import statement """
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ✔️ **程式碼說明**
#
# 1. 產生0到2$π$之間的1000個等間距點，作為參數t
# 2. 定義愛心的參數方程式: <br>
# $x = 16 \sin^3(t)$ <br>
# $y = 13 \cos(t) - 5 \cos(2t) - 2 \cos(3t) - \cos(4t)$

# %%
""" 使用參數方程式繪製愛心圖形 """

t = np.linspace(0, 2 * np.pi, 1000)
x = 16 * np.sin(t)**3
y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

plt.plot(x, y, 'r', linewidth=4)   # 以紅筆畫圖，線寬設定為4
plt.axis('off')             # 隱藏坐標軸
plt.title("Heart Shape", fontsize=12) # 設定圖片標題及字體大小
# Out:
# Text(0.5, 1.0, 'Heart Shape')
